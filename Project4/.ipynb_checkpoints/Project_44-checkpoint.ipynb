# %%
import csv
import json
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from scipy.spatial import Delaunay
from scipy.spatial import distance
from igraph import *
import matplotlib.pyplot as plt
import json
import numpy as np
import os
import random
import math

# %% [markdown]
# ### Q6

# %% [markdown]
# #### create graph

# %%
directory = os.path.abspath('/Users/bournsh/Desktop/UCLA_Studying/2020spring/ECE232/Project4/data')#
df = pd.read_csv(directory + '/los_angeles-censustracts-2019-4-All-MonthlyAggregate.csv')

# %%
df = df.iloc[:, 0:4]
df = df.loc[df['month']==12]
dec_df = df.drop(['month'], axis=1)

# %%
dec_df.head()
# Out:
#    sourceid  dstid  mean_travel_time
# 2       758    972            953.55
# 5      1197   2006           1213.18
# 6      2652    620            828.92
# 7      2427   2693           1742.80
# 8      2653    610            699.03

# %%
init_dec_df = dec_df.copy()
init_dec_df['sourceid'] = init_dec_df['sourceid'].astype(str)
init_dec_df['dstid'] = init_dec_df['dstid'].astype(str)

# %%
tuples_init = [tuple(x) for x in init_dec_df.values]
g_init = Graph.TupleList(tuples_init, directed = False, edge_attrs = 'weight')

# %%
summary(g_init)
# Out:
# IGRAPH UNW- 2649 1692450 --
# + attr: name (v), weight (e)

# %% [markdown]
# #### clear the duplicates

# %%
dec_array = np.asarray(dec_df) 
existing_paths = {}
existing_locations = np.unique(np.concatenate([dec_array[:,0],dec_array[:,1]]))
counter = 0
for row in dec_array:
    locations = tuple(np.sort(row[0:2]))
    if locations in existing_paths:
        existing_paths[locations].append(row[2])
        counter += 1
    else:
        existing_paths[locations] = [row[2]]

with open(directory + '/december_data.txt','w') as f:
    for locations in existing_paths:
        string = '{} {} {:.2f}\n'.format(int(locations[0]),int(locations[1]),np.mean(existing_paths[locations]))
        f.write(string)

# %%
g = Graph.Read(directory + '/december_data.txt', format='ncol', directed=False)
gcc = g.components().giant()
summary(g)
summary(gcc)
# Out:
# IGRAPH UNW- 2649 1004955 --
# + attr: name (v), weight (e)
# IGRAPH UNW- 2649 1004955 --
# + attr: name (v), weight (e)

# %% [markdown]
# #### get the json file

# %%
with open(directory+'/los_angeles_censustracts.json', 'r') as f:
    data_json = json.load(f)
data_json.keys()
# Out:
# dict_keys(['type', 'features'])

# %%
geo_df = data_json['features']

# %%
colname = ['ID', 'Display_Name', 'Longitude', 'Latitude']
map_df = pd.DataFrame(columns = colname)
map_df
# Out:
# Empty DataFrame
# Columns: [ID, Display_Name, Longitude, Latitude]
# Index: []

# %%
print(geo_df[0].keys())
print(geo_df[0]['properties'].keys())
print(geo_df[0]['geometry'].keys())
# Out:
# dict_keys(['type', 'properties', 'geometry'])
# dict_keys(['MOVEMENT_ID', 'TRACT', 'DISPLAY_NAME'])
# dict_keys(['type', 'coordinates'])

# %%
i = 1
for item in geo_df:
    map_df.loc[i, 'ID'] = item['properties']['MOVEMENT_ID']
    map_df.loc[i, 'Display_Name'] = item['properties']['DISPLAY_NAME']
    coors = item['geometry']['coordinates'][0][0]
    if isinstance(coors[0], list):
        longitude = 0
        latitude = 0

        for coor in coors:
            longitude = longitude+coor[0]
            latitude = latitude+coor[1]
            
        longitude = longitude/len(coors)
        latitude = latitude/len(coors)     
    else:
        coors = item['geometry']['coordinates'][0]
        longitude = 0
        latitude = 0

        for coor in coors:
            longitude = longitude+coor[0]
            latitude = latitude+coor[1]
            
        longitude = longitude/len(coors)
        latitude = latitude/len(coors)
#         longitude = coors[0]
#         latitude = coors[1]
        
    map_df.loc[i, 'Longitude'] = longitude
    map_df.loc[i, 'Latitude'] = latitude    
    i+=1

# %%
map_df
# Out:
#         ID         Display_Name Longitude Latitude
# 1        1  Census Tract 480302  -118.121  34.1031
# 2        2  Census Tract 480303  -118.138  34.0965
# 3        3  Census Tract 480304  -118.131  34.0963
# 4        4  Census Tract 480400  -118.132  34.1035
# 5        5  Census Tract 480500  -118.145  34.0987
# ...    ...                  ...       ...      ...
# 2712  2712  Census Tract 087902  -117.988   33.792
# 2713  2713  Census Tract 110006  -118.078  33.7962
# 2714  2714  Census Tract 110007  -118.083  33.7881
# 2715  2715  Census Tract 110008   -118.08   33.781
# 2716  2716  Census Tract 110604  -117.992   33.893
#
# [2716 rows x 4 columns]

# %% [markdown]
# #### map geo_coordinates with map information

# %%
gvs = g.vs()
for v in gvs:
    v["Display_Name"] = map_df.loc[map_df["ID"] == v['name']].iloc[:,1].values[0]
    v["Coordinate"] = (map_df.loc[map_df["ID"] == v['name']].iloc[:,2].values[0],
                       map_df.loc[map_df["ID"] == v['name']].iloc[:,3].values[0])
gcc = g.components().giant()

# %%
summary(g)
summary(gcc)
# Out:
# IGRAPH UNW- 2649 1004955 --
# + attr: Coordinate (v), Display_Name (v), name (v), weight (e)
# IGRAPH UNW- 2649 1004955 --
# + attr: Coordinate (v), Display_Name (v), name (v), weight (e)

# %% [markdown]
# ### Q7

# %%
mst = gcc.spanning_tree(weights = gcc.es['weight'])
vertices = mst.vs()
summary(mst)
# Out:
# IGRAPH UNW- 2649 2648 --
# + attr: Coordinate (v), Display_Name (v), name (v), weight (e)

# %%
for i in range(6):
    r = random.randint(0, len(vertices))
    print("Random point{}:".format(i+1))
    print("One endpoint:\nID: {}, Display_Name: {}".format(vertices[r]["name"], vertices[r]["Display_Name"]))
#    print("Coordinate: {}".format(vertices[r]["Coordinate"]))
    print("Another endpoint:\nID: {}, Display_Name: {}".format(vertices[r+1]["name"], vertices[r+1]["Display_Name"]))
    print('='*60)
#    print("Coordinate: {}\n".format(vertices[r+1]["Coordinate"]))
# Out:
# Random point1:
# One endpoint:
# ID: 1689, Display_Name: Census Tract 980015
# Another endpoint:
# ID: 2498, Display_Name: Census Tract 087102
# ============================================================
# Random point2:
# One endpoint:
# ID: 302, Display_Name: Census Tract 432802
# Another endpoint:
# ID: 2265, Display_Name: Census Tract 434004
# ============================================================
# Random point3:
# One endpoint:
# ID: 1030, Display_Name: Census Tract 143200
# Another endpoint:
# ID: 1108, Display_Name: Census Tract 190520
# ============================================================
# Random point4:
# One endpoint:
# ID: 1618, Display_Name: Census Tract 276604
# Another endpoint:
# ID: 1931, Display_Name: Census Tract 481103
# ============================================================
# Random point5:
# One endpoint:
# ID: 208, Display_Name: Census Tract 542501
# Another endpoint:
# ID: 1726, Display_Name: Census Tract 533701
# ============================================================
# Random point6:
# One endpoint:
# ID: 1602, Display_Name: Census Tract 274202
# Another endpoint:
# ID: 1993, Display_Name: Census Tract 535603
# ============================================================

# %% [markdown]
# ### Q8

# %%
def is_trangle(max_index, combined_set, *args):
    current_set = ()
    indices = []
    weights = []
    for index in range(3):
        indices.append(random.randint(0, max_index))
    current_set = tuple(sorted(indices))
    
    while current_set in combined_set:
        for index in range(3):
            indices.append(random.randint(0, max_index))
        current_set = tuple(sorted(indices))
    
    for e in current_set:
        weights.append(gcc_es[e]['weight'])
    if (weights[0] < weights[1] + weights[2] and weights[1] < weights[0] + weights[2] and weights[2] < weights[0] + weights[1]):
        return True, weights, current_set
    else:
        return False, weights, current_set

# %%
max_idx = len(gcc.vs()) - 1
gcc_vertices = gcc.vs()
gcc_es = EdgeSeq(gcc)
num_triangle = 1000
total_set = set()
num_satisfied = 0
num = 0

# %%
def result_show(satisify):
    print('='*50,'triangle',num+1)
    
    edges = []
    start_nodes = []
    end_nodes = []
    for e in current_set:
        edges.append(gcc_es[e])
        
        source_vertex = gcc.vs[gcc_es[e].source]
        target_vertex = gcc.vs[gcc_es[e].target]
        
        start_nodes.append(source_vertex['Display_Name'])
        end_nodes.append(target_vertex['Display_Name'])
    for i in range(3):
        print(start_nodes[i], '---', end_nodes[i])
    if satisify:
        print('Is Triangle')
    else:
        print('Not a Triangle')

# %%
while num<num_triangle:
    for i in range(3):
        satisfy, weights, current_set = is_trangle(max_idx, total_set)
        if satisfy:
            break
    total_set.add(current_set)
    if satisfy:
        num_satisfied+=1
    if num%100 == 0:
        result_show(satisfy)
    num+=1
print(str(num_satisfied/num_triangle))
# Out:
# ================================================== triangle 1
# Census Tract 195901 --- Census Tract 236000
# Census Tract 104204 --- Census Tract 186401
# Census Tract 208710 --- Census Tract 237201
# Is Triangle
# ================================================== triangle 101
# Census Tract 124105 --- Census Tract 195600
# Census Tract 271702 --- Census Tract 186203
# Census Tract 433307 --- Census Tract 406000
# Is Triangle
# ================================================== triangle 201
# Census Tract 207400 --- Census Tract 480704
# Census Tract 183820 --- Census Tract 238310
# Census Tract 224700 --- Census Tract 201700
# Is Triangle
# ================================================== triangle 301
# Census Tract 123510 --- Census Tract 211703
# Census Tract 533403 --- Census Tract 572201
# Census Tract 602301 --- Census Tract 238400
# Is Triangle
# ================================================== triangle 401
# Census Tract 670001 --- Census Tract 572100
# Census Tract 602600 --- Census Tract 232700
# Census Tract 551201 --- Census Tract 206032
# Is Triangle
# ================================================== triangle 501
# Census Tract 602600 --- Census Tract 536000
# Census Tract 239702 --- Census Tract 232200
# Census Tract 207900 --- Census Tract 461901
# Is Triangle
# ================================================== triangle 601
# Census Tract 238320 --- Census Tract 572900
# Census Tract 239701 --- Census Tract 461501
# Census Tract 124203 --- Census Tract 701000
# Is Triangle
# ================================================== triangle 701
# Census Tract 209401 --- Census Tract 211410
# Census Tract 212202 --- Census Tract 224420
# Census Tract 232700 --- Census Tract 241202
# Is Triangle
# ================================================== triangle 801
# Census Tract 207501 --- Census Tract 533806
# Census Tract 296401 --- Census Tract 670403
# Census Tract 192410 --- Census Tract 702201
# Is Triangle
# ================================================== triangle 901
# Census Tract 702600 --- Census Tract 106406
# Census Tract 199120 --- Census Tract 535300
# Census Tract 185100 --- Census Tract 099906
# Is Triangle
# 0.988

# %% [markdown]
# ### Q9

# %%
def create_a_walk(mst, walk, visited, mst_vset, *args):
    current_node = walk[-1]
    if len(walk) > 1 and current_node == walk[0]:
        return True
    else:
        edges = mst.es.select(_between = ([current_node],mst_vset))
        for edge in edges:
            if not edge in visited:
                visited.add(edge)
                node_tuple = edge.tuple
                if node_tuple[0] == current_node:
                    next_node = node_tuple[1]
                else:
                    next_node = node_tuple[0]

                walk.append(next_node)
                next_walk = create_a_walk(mst, walk, visited, mst_vset)
                if next_walk:
                    return True
                else:
                    walk.pop()
                    visited.remove(edge)
        return False

# %%
def eulerian_walk(mst, v, mst_vset, *args):    
    edges = mst.es.select(_source_in = [v])
    if len(edges) == 0: 
        return [v]
    else:
        walk = [v]
        visited = set()
        create_a_walk(mst, walk, visited, mst_vset)
        for i in range(len(walk) - 1):
            walk_edges = mst.es.select(_between = ([walk[i]], [walk[i+1]]))
            mst.delete_edges(walk_edges[0])
        results = []
        for node in walk:
            next_ewalk = eulerian_walk(mst, node, mst_vset)
            for e in next_ewalk:
                results.append(e)
        return results

# %%
def approximate_algorithm(g, *args):
    # find the minimum spanning tree T
    mst = g.spanning_tree(weights = gcc.es["weight"])
    edges = mst.es()
    edge_list = []
    for edge in edges:
        edge_list.append(edge.tuple)
        
    mst_temp = mst.as_undirected()
    mst_temp.add_edges(edge_list)
    
    mst_double = mst_temp.as_undirected()

    e_walk = eulerian_walk(mst_double, 0, mst_double.vs())

    path = []
    visited = set()
    for i in e_walk:
        if not i in visited:
            path.append(i)
            visited.add(i)
            
    total_weight = 0
    final_path = []
    for i in range(len(path) - 1):
        i_1 = path[i]
        i_2 = path[i + 1]

        edges = g.es.select(_between = ([i_1], [i_2]))
        if len(edges) > 0:
            total_weight += edges[0]['weight']
            final_path.append(i_1)
        else:
            total_weight += gcc.shortest_paths([i_1], [i_2], weights = gcc.es()['weight'])[0][0]
    return mst, total_weight, final_path

# %%
import sys
sys.setrecursionlimit(10000)

appro_mst, total_weight, final_path = approximate_algorithm(gcc)

# %%
print('total weight:', total_weight)
print('upper bound:', total_weight / sum(mst.es['weight']))
# Out:
# total weight: 465542.44000000047
# upper bound: 1.7300968643282872

# %% [markdown]
# ### Q10

# %%
final_locations = []
for i in final_path:
    final_locations.append(appro_mst.vs[i]['Display_Name'])

# %%
longitude = []
latitude = []

for i in final_path:
    longitude.append(appro_mst.vs[i]['Coordinate'][0])
    latitude.append(appro_mst.vs[i]['Coordinate'][1])

# %%
plt.figure(figsize = (25, 20))

plt.plot(longitude, latitude)
plt.xlabel('Longitude', fontsize = 18)
plt.ylabel('Latitude', fontsize = 18)
plt.title('Trajectory of TSP', fontsize = 18)
plt.show()

# %% [markdown]
# ### Q11

# %%
coor_df = map_df.copy()
coor_df = coor_df.iloc[:, [2,3]]
coor_df.head()
# Out:
#   Longitude Latitude
# 1  -118.121  34.1031
# 2  -118.138  34.0965
# 3  -118.131  34.0963
# 4  -118.132  34.1035
# 5  -118.145  34.0987

# %%
coor_list = []
for i in range(len(coor_df)):
    coor_list.append([coor_df.iloc[i, 0], coor_df.iloc[i, 1]])
coor_arr = np.asarray(coor_list)
tri = Delaunay(coor_arr)

# %%
plt.triplot(tri.points[:, 0], tri.points[:, 1], tri.simplices.copy())
plt.triplot(tri.points[:, 0], tri.points[:, 1], 'r.')
#plt.plot(tri.points[:, 0], tri.points[:, 1], 'o')
plt.show()

# %%
coor_list_2 = []
# gcc_vertices = gcc.vs()
for v in gcc_vertices:
    coor_list_2.append(list(v['Coordinate']))
coor_arr_2 = np.array(coor_list_2)

# %%
tri_2 = Delaunay(coor_arr_2)
plt.triplot(tri_2.points[:, 0], tri_2.points[:, 1], tri_2.simplices.copy())
plt.triplot(tri_2.points[:, 0], tri_2.points[:, 1],'r.')

plt.show()

# %% [markdown]
# ### Q12

# %%
def get_flow(dist, time):
    speed = dist/time
    flow = 2/(0.003/speed + 1/1800)
    return flow

# %%
gcc_flow = gcc
gcc_Es = EdgeSeq(gcc_flow)
for es in gcc_Es:
    vertex1 = es.tuple[0]
    vertex2 = es.tuple[1]
    coor_1 = gcc.vs[vertex1]['Coordinate']
    coor_2 = gcc.vs[vertex2]['Coordinate']
    dist = 69*distance.euclidean(coor_1, coor_2)
    time = es['weight']/3600
    if dist==0:
        continue
    flow = get_flow(dist, time)
    es['Flow'] = flow

gcc_flow.summary()
# Out:
# 'IGRAPH UNW- 2649 1004955 -- \n+ attr: Coordinate (v), Display_Name (v), name (v), Flow (e), weight (e)'

# %%
# for es in gcc_Es:
#     if es['Flow'] is not None:
#         flow = es['Flow']
#     else:
#         continue

# %%
total_flow, n = 0, 0
for es in gcc_Es:
    if es['Flow'] is not None:
        total_flow += es['Flow']
        n+=1
    else:
        continue
mean_flow = total_flow/n
print('The mean of the flow is {:.0f} cars/(hour.road)'.format(mean_flow))
# Out:
# The mean of the flow is 2941 cars/(hour.road)

# %% [markdown]
# ### Q13

# %%
dest_id = 0
source_id = 0
for i in range(len(gcc.vs())):
    if abs(round(gcc_flow.vs[i]['Coordinate'][0], 2)+118.56)<=0.02 and abs(round(gcc_flow.vs[i]['Coordinate'][1],2)-34.04)<=0.01:
        source_id = i
    if round(gcc_flow.vs[i]['Coordinate'][0],2) == -118.18 and round(gcc_flow.vs[i]['Coordinate'][1],2) == 33.77:
        dest_id = i

# %%
print(source_id, dest_id)
# Out:
# 1614 868

# %%
gcc_flow.vs[dest_id]['Coordinate']
# Out:
# (-118.17865950000001, 33.771767700000005)

# %%
gcc_flow.vs[source_id]
# Out:
# igraph.Vertex(<igraph.Graph object at 0x7fd53da17150>, 1614, {'name': '1523', 'Display_Name': 'Census Tract 262604', 'Coordinate': (-118.54625915050165, 34.048403046822735)})

# %%
gcc_flow.vs[source_id]['Coordinate']
# Out:
# (-118.54625915050165, 34.048403046822735)

# %%
gcc_maxflow = gcc_flow.maxflow(source_id, dest_id, capacity = 'Flow')

# %%
gcc_maxflow_value = gcc_flow.maxflow_value(source_id, dest_id, capacity = 'Flow')

# %%
print(gcc_maxflow_value)
# Out:
# 1475054.0002806964

# %%
gcc_disjointed_path = gcc_flow.edge_disjoint_paths(source_id, dest_id)
print(gcc_disjointed_path)
# Out:
# 504

# %%
x = tri_2.points[:,0]
y = tri_2.points[:,1]
plt.triplot(x, y, tri_2.simplices, color = "b")
plt.plot(x, y, 'o')
plt.title("Zoom-in Malibu neighbourhood produced by triangulation")
plt.ylabel("Latitude (Degree)")
plt.xlabel("Longitude (Degree)")
plt.ylim((34.04-0.06,34.04+0.06))
plt.xlim((-118.56-0.06,-118.56+0.06))

plt.plot(-118.54625915050165, 34.048403046822735, 'r.', ms = 25)
plt.show()

# %%
x = tri_2.points[:,0]
y = tri_2.points[:,1]
plt.triplot(x, y, tri_2.simplices, color = "b")
plt.plot(x, y, 'o')
plt.title("Zoom-in Longbeach neighbourhood produced by triangulation")
plt.ylabel("Latitude (Degree)")
plt.xlabel("Longitude (Degree)")
plt.ylim((33.77-0.06,33.77+0.06))
plt.xlim((-118.18-0.06,-118.18+0.06))

plt.plot(-118.17865950000001, 33.771767700000005, 'r.', ms=25)
plt.show()

# %% [markdown]
# ### Q14

# %%
plt.triplot(tri_2.points[:, 0], tri_2.points[:, 1], tri_2.simplices.copy())
plt.show()

# %%
def add_travel_time_edge(graph,triangle,thresh):
    edge12 = tuple(np.sort(triangle[:2]))
    edge13 = tuple(np.sort(triangle[0::2]))
    edge23 = tuple(np.sort(triangle[1:]))   
    
    time12 = get_time(edge12[0],edge12[1],uber_gcc_graph)
    time13 = get_time(edge13[0],edge13[1],uber_gcc_graph)
    time23 = get_time(edge23[0],edge23[1],uber_gcc_graph)
    
    if edge12 not in graph.keys() and time12 < thresh and time12 > 0:
        graph[edge12] = time12
    if edge13 not in graph.keys() and time13 < thresh and time13 > 0:
        graph[edge13] = time13
    if edge23 not in graph.keys() and time23 < thresh and time23 > 0:
        graph[edge23] = time23

# %%
triangulated_time_graph = {}
uber_gcc = gcc
uber_gcc_id = np.concatenate([uber_gcc[:, 0], uber_gcc[:, 1]])
uber_gcc_id = np.unique(uber_gcc_id).astype('int')

# %%
THRESH = 60*12
for triangle_idx in tri_2.simplices:
    triangle = [uber_gcc_id[triangle_idx[0]], uber_gcc_id[triangle_idx[1]], uber_gcc_id[triangle_idx[2]]]
    add_travel_time_edge(triangulated_time_graph, triangle, THRESH)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-61-4c3327417616> in <module>
#       1 THRESH = 60*12
#       2 for triangle_idx in tri_2.simplices:
# ----> 3     triangle = [uber_gcc_id[triangle_idx[0]], uber_gcc_id[triangle_idx[1]], uber_gcc_id[triangle_idx[2]]]
#       4     add_travel_time_edge(triangulated_time_graph, triangle, THRESH)
#
# IndexError: index 2646 is out of bounds for axis 0 with size 1035
